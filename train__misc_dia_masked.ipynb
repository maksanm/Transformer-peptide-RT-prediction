# %% [markdown]
# # Peptide Retention Time Prediction using Encoder-Only Transformer – Training Notebook
#
# This notebook trains a Encoder-Only Transformer model to predict peptide retention times from sequence.
#
# ---
#
# ## 1. Setup & Imports

# %%
import sys
sys.path.append('./src')  # so we can import rt_transformer.py

from rt_transformer import AATokenizer, PeptideRTDataset, PeptideRTEncoderModel, split_dataset, collate, run_epoch, compute_metrics

import torch
from torch.utils.data import DataLoader

import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Configuration
# Set data path, model hyperparameters, and training settings.

# %%
DATA_PATH = "data/misc_dia.txt"
MODEL_PATH = "models/misc_dia__masked.pt"

# Model config
BATCH_SIZE = 256
EPOCHS = 400
LEARNING_RATE = 5e-4
D_MODEL = 160
N_HEADS = 8
N_LAYERS = 5

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# Set random seeds for reproducibility
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
random.seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Using device: cuda

# %% [markdown]
# ## 3. Data Preparation
# Load the dataset, split into train/validation, and create DataLoaders.

# %%
# Initialize tokenizer and dataset
tokenizer = AATokenizer()
dataset = PeptideRTDataset(DATA_PATH, tokenizer)

# Split into train/val
train_ds, val_ds = split_dataset(dataset, val_ratio=0.05, seed=SEED)

# DataLoaders
coll = lambda b: collate(b, tokenizer.pad_id)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, collate_fn=coll)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, collate_fn=coll)

print(f"Train samples: {len(train_ds)}, Val samples: {len(val_ds)}")
# Out:
# Train samples: 139258, Val samples: 7329

# %% [markdown]
# ## 4. Model Initialization
# Create the Transformer model and optimizer.

# %%
model = PeptideRTEncoderModel(
    tokenizer,
    d_model=D_MODEL,
    n_heads=N_HEADS,
    d_ff=4*D_MODEL,
    n_layers=N_LAYERS
).to(DEVICE)

optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
loss_fn = torch.nn.SmoothL1Loss()

print(f"Model size: {sum(p.numel() for p in model.parameters() if p.requires_grad)} parameters")
# Out:
# Model size: 1576802 parameters

# %% [markdown]
# ## 5. Training Loop
# Train the model and monitor loss.

# %%
train_losses, val_losses = [], []

#model.load_state_dict(torch.load(MODEL_PATH, weights_only=True))
best_val_loss = float("inf")
for epoch in range(0, EPOCHS):
    train_loss = train_loss = run_epoch(
        model, train_loader, loss_fn, optimizer, DEVICE,
        mask_randomly=True,
        pad_id=tokenizer.pad_id,
        unk_id=tokenizer.unk_id,
        mask_frac=0.10,
        mask_batch_probability=0.2
    )
    val_loss   = run_epoch(model, val_loader,   loss_fn, None, DEVICE)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    log_msg = f"Epoch {epoch:3d} | train loss {train_loss:.6f} | val loss {val_loss:.6f}"
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), MODEL_PATH)
        log_msg += "  <-- best val loss so far, model saved"
    print(log_msg)
# Out:
# Epoch   0 | train loss 0.004630 | val loss 0.000952  <-- best val loss so far, model saved
# Epoch   1 | train loss 0.001462 | val loss 0.001041
# Epoch   2 | train loss 0.001329 | val loss 0.000842  <-- best val loss so far, model saved
# Epoch   3 | train loss 0.001231 | val loss 0.000812  <-- best val loss so far, model saved
# Epoch   4 | train loss 0.001237 | val loss 0.000904
# Epoch   5 | train loss 0.001169 | val loss 0.000832
# Epoch   6 | train loss 0.001109 | val loss 0.000643  <-- best val loss so far, model saved
# Epoch   7 | train loss 0.001015 | val loss 0.000698
# Epoch   8 | train loss 0.001037 | val loss 0.000576  <-- best val loss so far, model saved
# Epoch   9 | train loss 0.000904 | val loss 0.000452  <-- best val loss so far, model saved
# Epoch  10 | train loss 0.000900 | val loss 0.000474
# Epoch  11 | train loss 0.000842 | val loss 0.000597
# Epoch  12 | train loss 0.000831 | val loss 0.000453
# Epoch  13 | train loss 0.000805 | val loss 0.000421  <-- best val loss so far, model saved
# Epoch  14 | train loss 0.000776 | val loss 0.000480
# Epoch  15 | train loss 0.000776 | val loss 0.000333  <-- best val loss so far, model saved
# Epoch  16 | train loss 0.000807 | val loss 0.000332  <-- best val loss so far, model saved
# Epoch  17 | train loss 0.000764 | val loss 0.000377
# Epoch  18 | train loss 0.000732 | val loss 0.000333
# Epoch  19 | train loss 0.000704 | val loss 0.000301  <-- best val loss so far, model saved
# Epoch  20 | train loss 0.000666 | val loss 0.000375
# Epoch  21 | train loss 0.000693 | val loss 0.000273  <-- best val loss so far, model saved
# Epoch  22 | train loss 0.000634 | val loss 0.000294
# Epoch  23 | train loss 0.000735 | val loss 0.000275
# Epoch  24 | train loss 0.000669 | val loss 0.000272  <-- best val loss so far, model saved
# Epoch  25 | train loss 0.000681 | val loss 0.000401
# Epoch  26 | train loss 0.000685 | val loss 0.000317
# Epoch  27 | train loss 0.000628 | val loss 0.000268  <-- best val loss so far, model saved
# Epoch  28 | train loss 0.000657 | val loss 0.000551
# Epoch  29 | train loss 0.000676 | val loss 0.000328
# Epoch  30 | train loss 0.000662 | val loss 0.000256  <-- best val loss so far, model saved
# Epoch  31 | train loss 0.000659 | val loss 0.000285
# Epoch  32 | train loss 0.000611 | val loss 0.000275
# Epoch  33 | train loss 0.000652 | val loss 0.000245  <-- best val loss so far, model saved
# Epoch  34 | train loss 0.000574 | val loss 0.000296
# Epoch  35 | train loss 0.000668 | val loss 0.000284
# Epoch  36 | train loss 0.000590 | val loss 0.000269
# Epoch  37 | train loss 0.000599 | val loss 0.000258
# Epoch  38 | train loss 0.000619 | val loss 0.000259
# Epoch  39 | train loss 0.000574 | val loss 0.000235  <-- best val loss so far, model saved
# Epoch  40 | train loss 0.000558 | val loss 0.000289
# Epoch  41 | train loss 0.000628 | val loss 0.000247
# Epoch  42 | train loss 0.000606 | val loss 0.000238
# Epoch  43 | train loss 0.000577 | val loss 0.000214  <-- best val loss so far, model saved
# Epoch  44 | train loss 0.000593 | val loss 0.000227
# Epoch  45 | train loss 0.000516 | val loss 0.000214
# Epoch  46 | train loss 0.000554 | val loss 0.000235
# Epoch  47 | train loss 0.000512 | val loss 0.000222
# Epoch  48 | train loss 0.000494 | val loss 0.000261
# Epoch  49 | train loss 0.000576 | val loss 0.000255
# Epoch  50 | train loss 0.000570 | val loss 0.000216
# Epoch  51 | train loss 0.000554 | val loss 0.000216
# Epoch  52 | train loss 0.000522 | val loss 0.000323
# Epoch  53 | train loss 0.000526 | val loss 0.000216
# Epoch  54 | train loss 0.000542 | val loss 0.000218
# Epoch  55 | train loss 0.000551 | val loss 0.000257
# Epoch  56 | train loss 0.000482 | val loss 0.000200  <-- best val loss so far, model saved
# Epoch  57 | train loss 0.000543 | val loss 0.000242
# Epoch  58 | train loss 0.000561 | val loss 0.000211
# Epoch  59 | train loss 0.000524 | val loss 0.000191  <-- best val loss so far, model saved
# Epoch  60 | train loss 0.000534 | val loss 0.000209
# Epoch  61 | train loss 0.000533 | val loss 0.000205
# Epoch  62 | train loss 0.000539 | val loss 0.000202
# Epoch  63 | train loss 0.000512 | val loss 0.000205
# Epoch  64 | train loss 0.000484 | val loss 0.000207
# Epoch  65 | train loss 0.000485 | val loss 0.000194
# Epoch  66 | train loss 0.000485 | val loss 0.000280
# Epoch  67 | train loss 0.000443 | val loss 0.000197
# Epoch  68 | train loss 0.000540 | val loss 0.000217
# Epoch  69 | train loss 0.000520 | val loss 0.000231
# Epoch  70 | train loss 0.000455 | val loss 0.000200
# Epoch  71 | train loss 0.000517 | val loss 0.000197
# Epoch  72 | train loss 0.000494 | val loss 0.000218
# Epoch  73 | train loss 0.000487 | val loss 0.000251
# Epoch  74 | train loss 0.000553 | val loss 0.000219
# Epoch  75 | train loss 0.000540 | val loss 0.000220
# Epoch  76 | train loss 0.000439 | val loss 0.000179  <-- best val loss so far, model saved
# Epoch  77 | train loss 0.000530 | val loss 0.000234
# Epoch  78 | train loss 0.000479 | val loss 0.000213
# Epoch  79 | train loss 0.000544 | val loss 0.000194
# Epoch  80 | train loss 0.000480 | val loss 0.000185
# Epoch  81 | train loss 0.000495 | val loss 0.000192
# Epoch  82 | train loss 0.000502 | val loss 0.000208
# Epoch  83 | train loss 0.000522 | val loss 0.000192
# Epoch  84 | train loss 0.000518 | val loss 0.000290
# Epoch  85 | train loss 0.000461 | val loss 0.000181
# Epoch  86 | train loss 0.000522 | val loss 0.000209
# Epoch  87 | train loss 0.000484 | val loss 0.000196
# Epoch  88 | train loss 0.000472 | val loss 0.000229
# Epoch  89 | train loss 0.000471 | val loss 0.000203
# Epoch  90 | train loss 0.000511 | val loss 0.000190
# Epoch  91 | train loss 0.000439 | val loss 0.000205
# Epoch  92 | train loss 0.000523 | val loss 0.000201
# Epoch  93 | train loss 0.000465 | val loss 0.000191
# Epoch  94 | train loss 0.000537 | val loss 0.000175  <-- best val loss so far, model saved
# Epoch  95 | train loss 0.000514 | val loss 0.000219
# Epoch  96 | train loss 0.000486 | val loss 0.000242
# Epoch  97 | train loss 0.000485 | val loss 0.000184
# Epoch  98 | train loss 0.000459 | val loss 0.000201
# Epoch  99 | train loss 0.000395 | val loss 0.000208
# Epoch 100 | train loss 0.000491 | val loss 0.000188
# Epoch 101 | train loss 0.000489 | val loss 0.000189
# Epoch 102 | train loss 0.000491 | val loss 0.000206
# Epoch 103 | train loss 0.000501 | val loss 0.000200
# Epoch 104 | train loss 0.000440 | val loss 0.000202
# Epoch 105 | train loss 0.000460 | val loss 0.000231
# Epoch 106 | train loss 0.000538 | val loss 0.000236
# Epoch 107 | train loss 0.000463 | val loss 0.000196
# Epoch 108 | train loss 0.000448 | val loss 0.000166  <-- best val loss so far, model saved
# Epoch 109 | train loss 0.000484 | val loss 0.000192
# Epoch 110 | train loss 0.000443 | val loss 0.000184
# Epoch 111 | train loss 0.000479 | val loss 0.000196
# Epoch 112 | train loss 0.000477 | val loss 0.000184
# Epoch 113 | train loss 0.000468 | val loss 0.000215
# Epoch 114 | train loss 0.000478 | val loss 0.000175
# Epoch 115 | train loss 0.000464 | val loss 0.000187
# Epoch 116 | train loss 0.000473 | val loss 0.000170
# Epoch 117 | train loss 0.000472 | val loss 0.000213
# Epoch 118 | train loss 0.000486 | val loss 0.000191
# Epoch 119 | train loss 0.000497 | val loss 0.000188
# Epoch 120 | train loss 0.000470 | val loss 0.000196
# Epoch 121 | train loss 0.000450 | val loss 0.000176
# Epoch 122 | train loss 0.000458 | val loss 0.000226
# Epoch 123 | train loss 0.000487 | val loss 0.000205
# Epoch 124 | train loss 0.000447 | val loss 0.000178
# Epoch 125 | train loss 0.000552 | val loss 0.000218
# Epoch 126 | train loss 0.000448 | val loss 0.000182
# Epoch 127 | train loss 0.000443 | val loss 0.000203
# Epoch 128 | train loss 0.000454 | val loss 0.000237
# Epoch 129 | train loss 0.000469 | val loss 0.000170
# Epoch 130 | train loss 0.000463 | val loss 0.000170
# Epoch 131 | train loss 0.000464 | val loss 0.000167
# Epoch 132 | train loss 0.000484 | val loss 0.000177
# Epoch 133 | train loss 0.000524 | val loss 0.000207
# Epoch 134 | train loss 0.000439 | val loss 0.000178
# Epoch 135 | train loss 0.000440 | val loss 0.000177
# Epoch 136 | train loss 0.000454 | val loss 0.000218
# Epoch 137 | train loss 0.000528 | val loss 0.000178
# Epoch 138 | train loss 0.000451 | val loss 0.000179
# Epoch 139 | train loss 0.000442 | val loss 0.000177
# Epoch 140 | train loss 0.000465 | val loss 0.000178
# Epoch 141 | train loss 0.000433 | val loss 0.000180
# Epoch 142 | train loss 0.000497 | val loss 0.000180
# Epoch 143 | train loss 0.000434 | val loss 0.000183
# Epoch 144 | train loss 0.000447 | val loss 0.000200
# Epoch 145 | train loss 0.000482 | val loss 0.000187
# Epoch 146 | train loss 0.000462 | val loss 0.000188
# Epoch 147 | train loss 0.000465 | val loss 0.000171
# Epoch 148 | train loss 0.000436 | val loss 0.000180
# Epoch 149 | train loss 0.000393 | val loss 0.000206
# Epoch 150 | train loss 0.000443 | val loss 0.000179
# Epoch 151 | train loss 0.000390 | val loss 0.000166
# Epoch 152 | train loss 0.000429 | val loss 0.000176
# Epoch 153 | train loss 0.000433 | val loss 0.000164  <-- best val loss so far, model saved
# Epoch 154 | train loss 0.000470 | val loss 0.000193
# Epoch 155 | train loss 0.000431 | val loss 0.000179
# Epoch 156 | train loss 0.000462 | val loss 0.000191
# Epoch 157 | train loss 0.000441 | val loss 0.000163  <-- best val loss so far, model saved
# Epoch 158 | train loss 0.000486 | val loss 0.000184
# Epoch 212 | train loss 0.000427 | val loss 0.000169
# Epoch 213 | train loss 0.000423 | val loss 0.000170
# Epoch 214 | train loss 0.000405 | val loss 0.000169
# Epoch 215 | train loss 0.000433 | val loss 0.000160
# Epoch 216 | train loss 0.000464 | val loss 0.000193
# Epoch 217 | train loss 0.000431 | val loss 0.000172
# Epoch 218 | train loss 0.000389 | val loss 0.000170
# Epoch 219 | train loss 0.000421 | val loss 0.000199
# Epoch 220 | train loss 0.000384 | val loss 0.000169
# Epoch 221 | train loss 0.000470 | val loss 0.000171
# Epoch 222 | train loss 0.000412 | val loss 0.000175
# Epoch 223 | train loss 0.000437 | val loss 0.000164
# Epoch 224 | train loss 0.000409 | val loss 0.000185
# Epoch 225 | train loss 0.000416 | val loss 0.000184
# Epoch 226 | train loss 0.000392 | val loss 0.000178
# Epoch 227 | train loss 0.000394 | val loss 0.000171
# Epoch 228 | train loss 0.000457 | val loss 0.000200
# Epoch 229 | train loss 0.000392 | val loss 0.000160
# Epoch 230 | train loss 0.000429 | val loss 0.000155
# Epoch 231 | train loss 0.000423 | val loss 0.000162
# Epoch 232 | train loss 0.000385 | val loss 0.000161
# Epoch 233 | train loss 0.000450 | val loss 0.000171
# Epoch 234 | train loss 0.000397 | val loss 0.000156
# Epoch 235 | train loss 0.000410 | val loss 0.000183
# Epoch 236 | train loss 0.000455 | val loss 0.000163
# Epoch 237 | train loss 0.000450 | val loss 0.000177
# Epoch 238 | train loss 0.000425 | val loss 0.000231
# Epoch 239 | train loss 0.000363 | val loss 0.000179
# Epoch 240 | train loss 0.000430 | val loss 0.000193
# Epoch 241 | train loss 0.000447 | val loss 0.000169
# Epoch 242 | train loss 0.000424 | val loss 0.000153  <-- best val loss so far, model saved
# Epoch 243 | train loss 0.000445 | val loss 0.000181
# Epoch 244 | train loss 0.000448 | val loss 0.000181
# Epoch 245 | train loss 0.000446 | val loss 0.000157
# Epoch 246 | train loss 0.000378 | val loss 0.000147  <-- best val loss so far, model saved
# Epoch 247 | train loss 0.000415 | val loss 0.000170
# Epoch 248 | train loss 0.000427 | val loss 0.000185
# Epoch 249 | train loss 0.000437 | val loss 0.000178
# Epoch 250 | train loss 0.000412 | val loss 0.000177
# Epoch 251 | train loss 0.000418 | val loss 0.000168
# Epoch 252 | train loss 0.000446 | val loss 0.000181
# Epoch 253 | train loss 0.000403 | val loss 0.000173
# Epoch 254 | train loss 0.000402 | val loss 0.000185
# Epoch 255 | train loss 0.000398 | val loss 0.000152
# Epoch 256 | train loss 0.000425 | val loss 0.000178
# Epoch 257 | train loss 0.000410 | val loss 0.000158
# Epoch 258 | train loss 0.000444 | val loss 0.000162
# Epoch 259 | train loss 0.000408 | val loss 0.000158
# Epoch 260 | train loss 0.000401 | val loss 0.000186
# Epoch 261 | train loss 0.000387 | val loss 0.000189
# Epoch 262 | train loss 0.000376 | val loss 0.000169
# Epoch 263 | train loss 0.000412 | val loss 0.000158
# Epoch 264 | train loss 0.000424 | val loss 0.000173
# Epoch 265 | train loss 0.000429 | val loss 0.000164
# Epoch 374 | train loss 0.000379 | val loss 0.000164
# Epoch 375 | train loss 0.000442 | val loss 0.000156
# Epoch 376 | train loss 0.000355 | val loss 0.000180
# Epoch 377 | train loss 0.000443 | val loss 0.000163
# Epoch 378 | train loss 0.000387 | val loss 0.000154
# Epoch 379 | train loss 0.000410 | val loss 0.000169
# Epoch 380 | train loss 0.000378 | val loss 0.000150
# Epoch 381 | train loss 0.000435 | val loss 0.000166
# Epoch 382 | train loss 0.000339 | val loss 0.000166
# Epoch 383 | train loss 0.000392 | val loss 0.000170
# Epoch 384 | train loss 0.000421 | val loss 0.000171
# Epoch 385 | train loss 0.000434 | val loss 0.000166
# Epoch 386 | train loss 0.000404 | val loss 0.000172
# Epoch 387 | train loss 0.000428 | val loss 0.000155
# Epoch 388 | train loss 0.000393 | val loss 0.000163
# Epoch 389 | train loss 0.000432 | val loss 0.000201
# Epoch 390 | train loss 0.000398 | val loss 0.000208
# Epoch 391 | train loss 0.000427 | val loss 0.000162
# Epoch 392 | train loss 0.000373 | val loss 0.000162
# Epoch 393 | train loss 0.000378 | val loss 0.000168
# Epoch 394 | train loss 0.000437 | val loss 0.000160
# Epoch 395 | train loss 0.000421 | val loss 0.000155
# Epoch 396 | train loss 0.000377 | val loss 0.000162
# Epoch 397 | train loss 0.000434 | val loss 0.000156
# Epoch 398 | train loss 0.000422 | val loss 0.000159
# Epoch 399 | train loss 0.000388 | val loss 0.000154

# %% [markdown]
# ## 6. Plot Training Curve

# %%
plt.figure(figsize=(10, 8))
plt.plot(train_losses, label='Train loss')
plt.plot(val_losses, label='Val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Compute Main Metrics for Trained Model

# %%
model.load_state_dict(torch.load(MODEL_PATH, weights_only=True))

model.eval()
all_preds, all_trues = [], []
with torch.no_grad():
    for seqs, mask, rts in val_loader:
        seqs, mask, rts = seqs.to(DEVICE), mask.to(DEVICE), rts.to(DEVICE)
        preds = model(seqs, mask)
        all_preds.append(preds.cpu())
        all_trues.append(rts.cpu())
all_preds = torch.cat(all_preds)
all_trues = torch.cat(all_trues)

metrics = compute_metrics(all_preds, all_trues)
print("\nValidation metrics for model:")
for k, v in metrics.items():
    print(f"{k:10s}: {v:.5f}")
# Out:
# c:\Users\mmakaranka\AppData\Local\pypoetry\Cache\virtualenvs\peptide-rt-transformer-KivCupBj-py3.12\Lib\site-packages\torch\nn\modules\transformer.py:505: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\NestedTensorImpl.cpp:182.)
#   output = torch._nested_tensor_from_mask(
# Validation metrics for model:
# MAE       : 0.01198
# MSE       : 0.00029
# RMSE      : 0.01712
# Max_Abs_Error: 0.26030
# Median_Abs_Error: 0.00873
# Mean_Abs_Percentage_Error: 0.03168
# Std_Error : 0.01696
# Std_True  : 0.18900
# Std_Pred  : 0.18819
# R2        : 0.99180
# Explained_Variance: 0.99195
# Pearson   : 0.99597
# Spearman  : 0.99703
