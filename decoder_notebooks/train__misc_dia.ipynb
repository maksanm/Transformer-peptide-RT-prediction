# %% [markdown]
# # Training - `misc-dia`
#
# This notebook trains a Decoder-Only Transformer model to predict peptide retention times from sequence on `misc-dia` dataset.
#
# ---
#
# ## 1. Setup & Imports

# %%
import sys
sys.path.append('../src')

from rt_transformer import AATokenizer, PeptideRTDataset, PeptideRTDecoderModel, split_dataset, collate, run_epoch, compute_metrics

import torch
from torch.utils.data import DataLoader

import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Configuration
# Set data path, model hyperparameters, and training settings.

# %%
DATA_PATH = "../data/misc_dia.txt"
MODEL_PATH = "../models/misc_dia_decoder.pt"

# Model config
BATCH_SIZE = 256
EPOCHS = 300
LEARNING_RATE = 1e-3

# Parameters selected by HPO
D_MODEL = 192
N_HEADS = 4
N_LAYERS = 3
N_QUERIES = 20
DISABLE_SELF_ATTN = False

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# Set random seeds for reproducibility
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
random.seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Using device: cuda

# %% [markdown]
# ## 3. Data Preparation
# Load the dataset, split into train/validation, and create DataLoaders.

# %%
# Initialize tokenizer and dataset
tokenizer = AATokenizer()
dataset = PeptideRTDataset(DATA_PATH, tokenizer)

# Split into train/val
train_ds, val_ds = split_dataset(dataset, val_ratio=0.05, seed=SEED)

# DataLoaders
coll = lambda b: collate(b, tokenizer.pad_id)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, collate_fn=coll)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, collate_fn=coll)

print(f"Train samples: {len(train_ds)}, Val samples: {len(val_ds)}")
# Out:
# Train samples: 139258, Val samples: 7329

# %% [markdown]
# ## 4. Model Initialization
# Create the Transformer model and optimizer.

# %%
model = PeptideRTDecoderModel(
    tokenizer,
    d_model=D_MODEL,
    n_heads=N_HEADS,
    d_ff=4*D_MODEL,
    n_layers=N_LAYERS,
    n_queries=N_QUERIES,
    disable_self_attn=DISABLE_SELF_ATTN
).to(DEVICE)

optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
loss_fn = torch.nn.SmoothL1Loss()

print(f"Model size: {sum(p.numel() for p in model.parameters() if p.requires_grad)} parameters")
# Out:
# Model size: 1826882 parameters

# %% [markdown]
# ## 5. Training Loop
# Train the model and monitor loss.

# %%
train_losses, val_losses = [], []

#model.load_state_dict(torch.load(MODEL_PATH, weights_only=True))
best_val_loss = float("inf")
for epoch in range(0, EPOCHS):
    train_loss = run_epoch(model, train_loader, loss_fn, optimizer, DEVICE)
    val_loss   = run_epoch(model, val_loader,   loss_fn, None, DEVICE)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    log_msg = f"Epoch {epoch:3d} | train loss {train_loss:.6f} | val loss {val_loss:.6f}"
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), MODEL_PATH)
        log_msg += "  <-- best val loss so far, model saved"
    print(log_msg)
# Out:
# Epoch   0 | train loss 0.007119 | val loss 0.001415  <-- best val loss so far, model saved
# Epoch   1 | train loss 0.001260 | val loss 0.000836  <-- best val loss so far, model saved
# Epoch   2 | train loss 0.001091 | val loss 0.000772  <-- best val loss so far, model saved
# Epoch   3 | train loss 0.000966 | val loss 0.000726  <-- best val loss so far, model saved
# Epoch   4 | train loss 0.000855 | val loss 0.000673  <-- best val loss so far, model saved
# Epoch   5 | train loss 0.000841 | val loss 0.000602  <-- best val loss so far, model saved
# Epoch   6 | train loss 0.000787 | val loss 0.000573  <-- best val loss so far, model saved
# Epoch   7 | train loss 0.000705 | val loss 0.000587
# Epoch   8 | train loss 0.000666 | val loss 0.000654
# Epoch   9 | train loss 0.000644 | val loss 0.000470  <-- best val loss so far, model saved
# Epoch  10 | train loss 0.000617 | val loss 0.000522
# Epoch  11 | train loss 0.000619 | val loss 0.000496
# Epoch  12 | train loss 0.000617 | val loss 0.000488
# Epoch  13 | train loss 0.000590 | val loss 0.000528
# Epoch  14 | train loss 0.000565 | val loss 0.000456  <-- best val loss so far, model saved
# Epoch  15 | train loss 0.000579 | val loss 0.000455  <-- best val loss so far, model saved
# Epoch  16 | train loss 0.000561 | val loss 0.000486
# Epoch  17 | train loss 0.000573 | val loss 0.000598
# Epoch  18 | train loss 0.000609 | val loss 0.000504
# Epoch  19 | train loss 0.000602 | val loss 0.000503
# Epoch  20 | train loss 0.000580 | val loss 0.000509
# Epoch  21 | train loss 0.000570 | val loss 0.001174
# Epoch  22 | train loss 0.000553 | val loss 0.000601
# Epoch  23 | train loss 0.000539 | val loss 0.000603
# Epoch  24 | train loss 0.000520 | val loss 0.000825
# Epoch  25 | train loss 0.000509 | val loss 0.000538
# Epoch  26 | train loss 0.000491 | val loss 0.000812
# Epoch  27 | train loss 0.000492 | val loss 0.000572
# Epoch  28 | train loss 0.000475 | val loss 0.000609
# Epoch  29 | train loss 0.000468 | val loss 0.000565
# Epoch  30 | train loss 0.000456 | val loss 0.000519
# Epoch  31 | train loss 0.000454 | val loss 0.000693
# Epoch  32 | train loss 0.000451 | val loss 0.000821
# Epoch  33 | train loss 0.000436 | val loss 0.000991
# Epoch  34 | train loss 0.000440 | val loss 0.000617
# Epoch  35 | train loss 0.000434 | val loss 0.000836
# Epoch  36 | train loss 0.000421 | val loss 0.000872
# Epoch  37 | train loss 0.000416 | val loss 0.000794
# Epoch  38 | train loss 0.000415 | val loss 0.000934
# Epoch  39 | train loss 0.000409 | val loss 0.000901
# Epoch  40 | train loss 0.000406 | val loss 0.000708
# Epoch  41 | train loss 0.000398 | val loss 0.000836
# Epoch  42 | train loss 0.000396 | val loss 0.000699
# Epoch  43 | train loss 0.000382 | val loss 0.000758
# Epoch  44 | train loss 0.000390 | val loss 0.000830
# Epoch  45 | train loss 0.000386 | val loss 0.000950
# Epoch  46 | train loss 0.000375 | val loss 0.000701
# Epoch  47 | train loss 0.000370 | val loss 0.000794
# Epoch  48 | train loss 0.000365 | val loss 0.000847
# Epoch  49 | train loss 0.000361 | val loss 0.000695
# Epoch  50 | train loss 0.000350 | val loss 0.000994
# Epoch  51 | train loss 0.000354 | val loss 0.000789
# Epoch  52 | train loss 0.000352 | val loss 0.001027
# Epoch  53 | train loss 0.000346 | val loss 0.000950
# Epoch 268 | train loss 0.000167 | val loss 0.000658
# Epoch 269 | train loss 0.000161 | val loss 0.000688
# Epoch 270 | train loss 0.000164 | val loss 0.000607
# Epoch 271 | train loss 0.000162 | val loss 0.000688
# Epoch 272 | train loss 0.000165 | val loss 0.000719
# Epoch 273 | train loss 0.000165 | val loss 0.000632
# Epoch 274 | train loss 0.000161 | val loss 0.000655
# Epoch 275 | train loss 0.000163 | val loss 0.000683
# Epoch 276 | train loss 0.000165 | val loss 0.000713
# Epoch 277 | train loss 0.000159 | val loss 0.000664
# Epoch 278 | train loss 0.000162 | val loss 0.000650
# Epoch 279 | train loss 0.000159 | val loss 0.000728
# Epoch 280 | train loss 0.000162 | val loss 0.000707
# Epoch 281 | train loss 0.000162 | val loss 0.000727
# Epoch 282 | train loss 0.000165 | val loss 0.000775
# Epoch 283 | train loss 0.000162 | val loss 0.000685
# Epoch 284 | train loss 0.000159 | val loss 0.000709
# Epoch 285 | train loss 0.000161 | val loss 0.000664
# Epoch 286 | train loss 0.000162 | val loss 0.000687
# Epoch 287 | train loss 0.000163 | val loss 0.000708
# Epoch 288 | train loss 0.000166 | val loss 0.000681
# Epoch 289 | train loss 0.000161 | val loss 0.000733
# Epoch 290 | train loss 0.000165 | val loss 0.000742
# Epoch 291 | train loss 0.000160 | val loss 0.000674
# Epoch 292 | train loss 0.000159 | val loss 0.000662
# Epoch 293 | train loss 0.000165 | val loss 0.000610
# Epoch 294 | train loss 0.000158 | val loss 0.000621
# Epoch 295 | train loss 0.000161 | val loss 0.000627
# Epoch 296 | train loss 0.000161 | val loss 0.000652
# Epoch 297 | train loss 0.000159 | val loss 0.000677
# Epoch 298 | train loss 0.000159 | val loss 0.000658
# Epoch 299 | train loss 0.000159 | val loss 0.000664

# %% [markdown]
# ## 6. Plot Training Curve

# %%
plt.figure(figsize=(10, 8))
plt.plot(train_losses, label='Train loss')
plt.plot(val_losses, label='Val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Compute Main Metrics for Trained Model

# %%
model.load_state_dict(torch.load(MODEL_PATH, weights_only=True))

model.eval()
all_preds, all_trues = [], []
with torch.no_grad():
    for seqs, mask, rts in val_loader:
        seqs, mask, rts = seqs.to(DEVICE), mask.to(DEVICE), rts.to(DEVICE)
        preds = model(seqs, mask)
        all_preds.append(preds.cpu())
        all_trues.append(rts.cpu())
all_preds = torch.cat(all_preds)
all_trues = torch.cat(all_trues)

metrics = compute_metrics(all_preds, all_trues)
print("\nValidation metrics for model:")
for k, v in metrics.items():
    print(f"{k:10s}: {v:.5f}")
# Out:
# Validation metrics for model:
# MAE       : 0.02165
# MSE       : 0.00091
# RMSE      : 0.03016
# Max_Abs_Error: 0.17483
# Median_Abs_Error: 0.01557
# Mean_Abs_Percentage_Error: 0.05314
# Std_Error : 0.02978
# Std_True  : 0.18900
# Std_Pred  : 0.18486
# R2        : 0.97453
# Explained_Variance: 0.97517
# Pearson   : 0.98755
# Spearman  : 0.99038
